# %%
import base64
import requests
import os
import pandas as pd

# Replace 'YOUR_OPENAI_API_KEY' with your actual OpenAI API key
api_key = "INSERT OWN API KEY HERE"

# Function to encode the image to base64
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# Replace 'path_to_your_image.jpg' with the path to your actual image file
# images path
image_file_path = os.fsencode(r"C:/Users/Jo/Documents/nitin_chatgpt_project/bone_fracture_project/bone_fracture_data/FracAtlas/images/Non_fractured")
# image_path = r""

# %%
# empty list of dictionaries
data = []

# run for first x files in the directory
for file in os.listdir(image_file_path)[:500]:
    # print(os.fsdecode(file))
    # filename = os.fsdecode(file)
    dict = {}
    if '.jpg' in file.decode('ascii'):
        base64_image = encode_image(os.path.join(image_file_path, file))
        # base64_image = encode_image(image_path)
        headers = {
          "Content-Type": "application/json",
          "Authorization": f"Bearer {api_key}"
        }

        payload = {
          "model": "gpt-4o",
          "messages": [
            {
              "role": "user",
              "content": [
                {"type": "text", "text": '''This is an X-ray from a patient. Based on the image, does the patient have 
                
                A) fracture or B) no fracture? Please only output the answer as A or B'''},
                {
                  "type": "image_url",
                  "image_url": {
                    "url": f"data:image/jpeg;base64,{base64_image}"
                  }
                }
              ]
            }
          ],
          "max_tokens": 300
        }

        # Make the API request and print out the response
        response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
        # parse out chatgpt message that we care about: add filename and the corresponding chatgpt response to dataframe
        try:
            print(file.decode('ascii'), ": ", response.json().get('choices')[0].get('message').get('content'))
            dict['filename'] = file.decode('ascii')
            dict['result'] = response.json().get('choices')[0].get('message').get('content')
            data.append(dict)
        # got an empty response rarely
        except TypeError:
            print(file.decode('ascii'), ": ", "")
            dict['filename'] = file.decode('ascii')
            dict['result'] = ""
            data.append(dict)
        # for anything else that I didn't expect
        except:
            print("Unresolved error: excluding the data")
# Out:
# IMG0000000.jpg :  B
# IMG0000001.jpg :  B
# IMG0000002.jpg :  A
# IMG0000003.jpg :  A
# IMG0000004.jpg :  A
# IMG0000005.jpg :  A
# IMG0000006.jpg :  A
# IMG0000007.jpg :  A
# IMG0000008.jpg :  A
# IMG0000009.jpg :  A
# IMG0000010.jpg :  A
# IMG0000011.jpg :  A
# IMG0000012.jpg :  A
# IMG0000013.jpg :  B
# IMG0000014.jpg :  B
# IMG0000015.jpg :  A
# IMG0000016.jpg :  A
# IMG0000017.jpg :  B
# IMG0000018.jpg :  B
# IMG0000020.jpg :  A
# IMG0000021.jpg :  B
# IMG0000022.jpg :  A
# IMG0000023.jpg :  A
# IMG0000024.jpg :  A
# IMG0000026.jpg :  B
# IMG0000027.jpg :  B
# IMG0000028.jpg :  A
# IMG0000029.jpg :  B
# IMG0000030.jpg :  A
# IMG0000031.jpg :  A
# IMG0000032.jpg :  A
